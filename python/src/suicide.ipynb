# %%
# ライブラリをインポート

# データ操作と数値計算のため
import pandas as pd
import numpy as np

# データ可視化のため
import matplotlib.pyplot as plt
import seaborn as sns

# 統計モデリングと計量経済分析のため
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col

# for ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
url = "https://www.fbc.keio.ac.jp/~tyabu/keiryo/suicide_data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   country_name  year  unemployment  suicide
# 0      Albania  2000         16.80      4.9
# 1    Australia  2000          6.28     12.7
# 2      Austria  2000          4.69     19.9
# 3   Azerbaijan  2000         11.78      3.1
# 4     Barbados  2000          9.35      2.6

# %% [markdown]
# # 11.3.1節の推定

# %%
model_1 = sm.OLS.from_formula('suicide ~ unemployment', data=df)
results_1 = model_1.fit(cov_type='cluster', cov_kwds={'groups': df['country_name']})
print(results_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                suicide   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                    0.8968
# Date:                Fri, 30 Aug 2024   Prob (F-statistic):              0.347
# Time:                        15:45:23   Log-Likelihood:                -4594.7
# No. Observations:                1280   AIC:                             9193.
# Df Residuals:                    1278   BIC:                             9204.
# Df Model:                           1
# Covariance Type:              cluster
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       11.9896      1.548      7.747      0.000       8.956      15.023
# unemployment     0.1422      0.150      0.947      0.344      -0.152       0.437
# ==============================================================================
# Omnibus:                      295.842   Durbin-Watson:                   1.567
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              647.237
# Skew:                           1.288   Prob(JB):                    2.85e-141
# Kurtosis:                       5.345   Cond. No.                         18.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %%
model_2 = sm.OLS.from_formula('suicide ~ unemployment + C(country_name)', data=df)
results_2 = model_2.fit(cov_type='cluster', cov_kwds={'groups': df['country_name']})
print(results_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                suicide   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     180.4
# Date:                Fri, 30 Aug 2024   Prob (F-statistic):           3.73e-20
# Time:                        15:41:46   Log-Likelihood:                -3016.8
# No. Observations:                1280   AIC:                             6164.
# Df Residuals:                    1215   BIC:                             6499.
# Df Model:                          64
# Covariance Type:              cluster
# =========================================================================================================
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 2.1301      1.019      2.090      0.037       0.132       4.128
# C(country_name)[T.Australia]              8.2063      0.639     12.851      0.000       6.955       9.458
# C(country_name)[T.Austria]               13.2667      0.669     19.842      0.000      11.956      14.577
# C(country_name)[T.Azerbaijan]             0.3710      0.560      0.663      0.507      -0.726       1.468
# C(country_name)[T.Barbados]              -3.4728      0.346    -10.030      0.000      -4.151      -2.794
# C(country_name)[T.Belgium]               16.1039      0.505     31.916      0.000      15.115      17.093
# C(country_name)[T.Bulgaria]               7.8686      0.295     26.681      0.000       7.291       8.447
# C(country_name)[T.Canada]                 8.1130      0.538     15.070      0.000       7.058       9.168
# C(country_name)[T.Chile]                  6.0340      0.435     13.865      0.000       5.181       6.887
# C(country_name)[T.Colombia]              -0.7816      0.243     -3.214      0.001      -1.258      -0.305
# C(country_name)[T.Costa Rica]             2.6862      0.494      5.434      0.000       1.717       3.655
# C(country_name)[T.Croatia]               12.7174      0.127     99.967      0.000      12.468      12.967
# C(country_name)[T.Cyprus]                -0.3095      0.479     -0.646      0.518      -1.249       0.630
# C(country_name)[T.Czech Republic]        11.2962      0.599     18.856      0.000      10.122      12.470
# C(country_name)[T.Denmark]                9.3775      0.631     14.867      0.000       8.141      10.614
# C(country_name)[T.Dominican Republic]     1.2495      0.581      2.151      0.031       0.111       2.388
# C(country_name)[T.El Salvador]            3.1634      0.647      4.887      0.000       1.895       4.432
# C(country_name)[T.Estonia]               16.8918      0.398     42.458      0.000      16.112      17.672
# C(country_name)[T.Finland]               14.5601      0.423     34.402      0.000      13.731      15.390
# C(country_name)[T.France]                13.1352      0.396     33.166      0.000      12.359      13.911
# C(country_name)[T.Georgia]                2.3109      0.041     56.948      0.000       2.231       2.390
# C(country_name)[T.Germany]                9.4188      0.543     17.357      0.000       8.355      10.482
# C(country_name)[T.Hungary]               20.1734      0.521     38.738      0.000      19.153      21.194
# C(country_name)[T.Iceland]                9.9029      0.744     13.314      0.000       8.445      11.361
# C(country_name)[T.Indonesia]             -0.8065      0.624     -1.292      0.196      -2.030       0.417
# C(country_name)[T.Ireland]                7.3445      0.461     15.925      0.000       6.441       8.248
# C(country_name)[T.Israel]                 1.4635      0.438      3.343      0.001       0.605       2.321
# C(country_name)[T.Italy]                  2.5413      0.364      6.988      0.000       1.828       3.254
# C(country_name)[T.Jamaica]               -3.2521      0.170    -19.183      0.000      -3.584      -2.920
# C(country_name)[T.Japan]                 18.7842      0.733     25.617      0.000      17.347      20.221
# C(country_name)[T.Kazakhstan]            26.8165      0.543     49.352      0.000      25.752      27.881
# C(country_name)[T.Korea, Rep.]           23.7660      0.787     30.205      0.000      22.224      25.308
# C(country_name)[T.Latvia]                19.4516      0.224     86.993      0.000      19.013      19.890
# C(country_name)[T.Lithuania]             33.1382      0.281    117.842      0.000      32.587      33.689
# C(country_name)[T.Luxembourg]             9.5068      0.690     13.769      0.000       8.154      10.860
# C(country_name)[T.Malaysia]               1.7650      0.789      2.236      0.025       0.218       3.312
# C(country_name)[T.Malta]                  2.6804      0.600      4.466      0.000       1.504       3.857
# C(country_name)[T.Mexico]                 1.5469      0.745      2.077      0.038       0.087       3.007
# C(country_name)[T.Moldova]               13.7738      0.605     22.757      0.000      12.588      14.960
# C(country_name)[T.Netherlands]            7.0615      0.693     10.189      0.000       5.703       8.420
# C(country_name)[T.New Zealand]            8.8974      0.665     13.385      0.000       7.595      10.200
# C(country_name)[T.North Macedonia]       -0.4107      1.077     -0.381      0.703      -2.521       1.699
# C(country_name)[T.Norway]                 9.3446      0.766     12.199      0.000       7.843      10.846
# C(country_name)[T.Panama]                 0.5171      0.539      0.959      0.338      -0.540       1.574
# C(country_name)[T.Paraguay]               0.9730      0.634      1.536      0.125      -0.269       2.215
# C(country_name)[T.Peru]                  -0.3001      0.724     -0.415      0.678      -1.719       1.119
# C(country_name)[T.Poland]                11.5423      0.243     47.529      0.000      11.066      12.018
# C(country_name)[T.Portugal]               7.5307      0.396     19.008      0.000       6.754       8.307
# C(country_name)[T.Romania]                8.1784      0.567     14.423      0.000       7.067       9.290
# C(country_name)[T.Russian Federation]    35.8853      0.555     64.623      0.000      34.797      36.974
# C(country_name)[T.Serbia]                10.9825      0.159     69.275      0.000      10.672      11.293
# C(country_name)[T.Slovak Republic]        7.7386      0.096     80.406      0.000       7.550       7.927
# C(country_name)[T.Slovenia]              19.9266      0.549     36.306      0.000      18.851      21.002
# C(country_name)[T.South Africa]          15.1882      0.865     17.567      0.000      13.494      16.883
# C(country_name)[T.Spain]                  1.7448      0.082     21.352      0.000       1.585       1.905
# C(country_name)[T.Sweden]                11.1786      0.543     20.603      0.000      10.115      12.242
# C(country_name)[T.Switzerland]           13.6277      0.731     18.630      0.000      12.194      15.061
# C(country_name)[T.Thailand]               6.5521      0.941      6.964      0.000       4.708       8.396
# C(country_name)[T.Turkey]                -2.0411      0.326     -6.255      0.000      -2.681      -1.402
# C(country_name)[T.Ukraine]               23.5958      0.426     55.370      0.000      22.761      24.431
# C(country_name)[T.United Kingdom]         4.6282      0.628      7.367      0.000       3.397       5.859
# C(country_name)[T.United States]          9.5908      0.611     15.691      0.000       8.393      10.789
# C(country_name)[T.Uruguay]               12.6656      0.342     37.063      0.000      11.996      13.335
# C(country_name)[T.Uzbekistan]             5.7626      0.752      7.664      0.000       4.289       7.236
# unemployment                              0.2549      0.069      3.674      0.000       0.119       0.391
# ==============================================================================
# Omnibus:                      195.615   Durbin-Watson:                   1.673
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2895.888
# Skew:                          -0.051   Prob(JB):                         0.00
# Kurtosis:                      10.368   Cond. No.                         680.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# # 11.4.2節の推定

# %%
model_3 = sm.OLS.from_formula('suicide ~ unemployment + C(country_name)', data=df)
results_3 = model_3.fit(cov_type='cluster', cov_kwds={'groups': df['country_name']})
print(results_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                suicide   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     180.4
# Date:                Fri, 30 Aug 2024   Prob (F-statistic):           3.73e-20
# Time:                        15:42:38   Log-Likelihood:                -3016.8
# No. Observations:                1280   AIC:                             6164.
# Df Residuals:                    1215   BIC:                             6499.
# Df Model:                          64
# Covariance Type:              cluster
# =========================================================================================================
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 2.1301      1.019      2.090      0.037       0.132       4.128
# C(country_name)[T.Australia]              8.2063      0.639     12.851      0.000       6.955       9.458
# C(country_name)[T.Austria]               13.2667      0.669     19.842      0.000      11.956      14.577
# C(country_name)[T.Azerbaijan]             0.3710      0.560      0.663      0.507      -0.726       1.468
# C(country_name)[T.Barbados]              -3.4728      0.346    -10.030      0.000      -4.151      -2.794
# C(country_name)[T.Belgium]               16.1039      0.505     31.916      0.000      15.115      17.093
# C(country_name)[T.Bulgaria]               7.8686      0.295     26.681      0.000       7.291       8.447
# C(country_name)[T.Canada]                 8.1130      0.538     15.070      0.000       7.058       9.168
# C(country_name)[T.Chile]                  6.0340      0.435     13.865      0.000       5.181       6.887
# C(country_name)[T.Colombia]              -0.7816      0.243     -3.214      0.001      -1.258      -0.305
# C(country_name)[T.Costa Rica]             2.6862      0.494      5.434      0.000       1.717       3.655
# C(country_name)[T.Croatia]               12.7174      0.127     99.967      0.000      12.468      12.967
# C(country_name)[T.Cyprus]                -0.3095      0.479     -0.646      0.518      -1.249       0.630
# C(country_name)[T.Czech Republic]        11.2962      0.599     18.856      0.000      10.122      12.470
# C(country_name)[T.Denmark]                9.3775      0.631     14.867      0.000       8.141      10.614
# C(country_name)[T.Dominican Republic]     1.2495      0.581      2.151      0.031       0.111       2.388
# C(country_name)[T.El Salvador]            3.1634      0.647      4.887      0.000       1.895       4.432
# C(country_name)[T.Estonia]               16.8918      0.398     42.458      0.000      16.112      17.672
# C(country_name)[T.Finland]               14.5601      0.423     34.402      0.000      13.731      15.390
# C(country_name)[T.France]                13.1352      0.396     33.166      0.000      12.359      13.911
# C(country_name)[T.Georgia]                2.3109      0.041     56.948      0.000       2.231       2.390
# C(country_name)[T.Germany]                9.4188      0.543     17.357      0.000       8.355      10.482
# C(country_name)[T.Hungary]               20.1734      0.521     38.738      0.000      19.153      21.194
# C(country_name)[T.Iceland]                9.9029      0.744     13.314      0.000       8.445      11.361
# C(country_name)[T.Indonesia]             -0.8065      0.624     -1.292      0.196      -2.030       0.417
# C(country_name)[T.Ireland]                7.3445      0.461     15.925      0.000       6.441       8.248
# C(country_name)[T.Israel]                 1.4635      0.438      3.343      0.001       0.605       2.321
# C(country_name)[T.Italy]                  2.5413      0.364      6.988      0.000       1.828       3.254
# C(country_name)[T.Jamaica]               -3.2521      0.170    -19.183      0.000      -3.584      -2.920
# C(country_name)[T.Japan]                 18.7842      0.733     25.617      0.000      17.347      20.221
# C(country_name)[T.Kazakhstan]            26.8165      0.543     49.352      0.000      25.752      27.881
# C(country_name)[T.Korea, Rep.]           23.7660      0.787     30.205      0.000      22.224      25.308
# C(country_name)[T.Latvia]                19.4516      0.224     86.993      0.000      19.013      19.890
# C(country_name)[T.Lithuania]             33.1382      0.281    117.842      0.000      32.587      33.689
# C(country_name)[T.Luxembourg]             9.5068      0.690     13.769      0.000       8.154      10.860
# C(country_name)[T.Malaysia]               1.7650      0.789      2.236      0.025       0.218       3.312
# C(country_name)[T.Malta]                  2.6804      0.600      4.466      0.000       1.504       3.857
# C(country_name)[T.Mexico]                 1.5469      0.745      2.077      0.038       0.087       3.007
# C(country_name)[T.Moldova]               13.7738      0.605     22.757      0.000      12.588      14.960
# C(country_name)[T.Netherlands]            7.0615      0.693     10.189      0.000       5.703       8.420
# C(country_name)[T.New Zealand]            8.8974      0.665     13.385      0.000       7.595      10.200
# C(country_name)[T.North Macedonia]       -0.4107      1.077     -0.381      0.703      -2.521       1.699
# C(country_name)[T.Norway]                 9.3446      0.766     12.199      0.000       7.843      10.846
# C(country_name)[T.Panama]                 0.5171      0.539      0.959      0.338      -0.540       1.574
# C(country_name)[T.Paraguay]               0.9730      0.634      1.536      0.125      -0.269       2.215
# C(country_name)[T.Peru]                  -0.3001      0.724     -0.415      0.678      -1.719       1.119
# C(country_name)[T.Poland]                11.5423      0.243     47.529      0.000      11.066      12.018
# C(country_name)[T.Portugal]               7.5307      0.396     19.008      0.000       6.754       8.307
# C(country_name)[T.Romania]                8.1784      0.567     14.423      0.000       7.067       9.290
# C(country_name)[T.Russian Federation]    35.8853      0.555     64.623      0.000      34.797      36.974
# C(country_name)[T.Serbia]                10.9825      0.159     69.275      0.000      10.672      11.293
# C(country_name)[T.Slovak Republic]        7.7386      0.096     80.406      0.000       7.550       7.927
# C(country_name)[T.Slovenia]              19.9266      0.549     36.306      0.000      18.851      21.002
# C(country_name)[T.South Africa]          15.1882      0.865     17.567      0.000      13.494      16.883
# C(country_name)[T.Spain]                  1.7448      0.082     21.352      0.000       1.585       1.905
# C(country_name)[T.Sweden]                11.1786      0.543     20.603      0.000      10.115      12.242
# C(country_name)[T.Switzerland]           13.6277      0.731     18.630      0.000      12.194      15.061
# C(country_name)[T.Thailand]               6.5521      0.941      6.964      0.000       4.708       8.396
# C(country_name)[T.Turkey]                -2.0411      0.326     -6.255      0.000      -2.681      -1.402
# C(country_name)[T.Ukraine]               23.5958      0.426     55.370      0.000      22.761      24.431
# C(country_name)[T.United Kingdom]         4.6282      0.628      7.367      0.000       3.397       5.859
# C(country_name)[T.United States]          9.5908      0.611     15.691      0.000       8.393      10.789
# C(country_name)[T.Uruguay]               12.6656      0.342     37.063      0.000      11.996      13.335
# C(country_name)[T.Uzbekistan]             5.7626      0.752      7.664      0.000       4.289       7.236
# unemployment                              0.2549      0.069      3.674      0.000       0.119       0.391
# ==============================================================================
# Omnibus:                      195.615   Durbin-Watson:                   1.673
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2895.888
# Skew:                          -0.051   Prob(JB):                         0.00
# Kurtosis:                      10.368   Cond. No.                         680.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# # 個別効果と時間効果を考慮した固定効果モデル

# %%
model_4 = sm.OLS.from_formula('suicide ~ unemployment + C(country_name) + C(year)', data=df)
results_4 = model_4.fit(cov_type='cluster', cov_kwds={'groups': df['country_name']})
print(results_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                suicide   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     25.91
# Date:                Fri, 30 Aug 2024   Prob (F-statistic):           4.56e-23
# Time:                        15:43:14   Log-Likelihood:                -2927.3
# No. Observations:                1280   AIC:                             6023.
# Df Residuals:                    1196   BIC:                             6456.
# Df Model:                          83
# Covariance Type:              cluster
# =========================================================================================================
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 4.8023      0.903      5.316      0.000       3.032       6.573
# C(country_name)[T.Australia]              7.4865      0.566     13.233      0.000       6.378       8.595
# C(country_name)[T.Austria]               12.5130      0.592     21.124      0.000      11.352      13.674
# C(country_name)[T.Azerbaijan]            -0.2597      0.496     -0.524      0.600      -1.231       0.712
# C(country_name)[T.Barbados]              -3.8631      0.307    -12.594      0.000      -4.464      -3.262
# C(country_name)[T.Belgium]               15.5352      0.447     34.753      0.000      14.659      16.411
# C(country_name)[T.Bulgaria]               7.5362      0.261     28.844      0.000       7.024       8.048
# C(country_name)[T.Canada]                 7.5062      0.477     15.738      0.000       6.571       8.441
# C(country_name)[T.Chile]                  5.5435      0.386     14.378      0.000       4.788       6.299
# C(country_name)[T.Colombia]              -1.0556      0.215     -4.900      0.000      -1.478      -0.633
# C(country_name)[T.Costa Rica]             2.1290      0.438      4.862      0.000       1.271       2.987
# C(country_name)[T.Croatia]               12.5740      0.113    111.565      0.000      12.353      12.795
# C(country_name)[T.Cyprus]                -0.8496      0.424     -2.001      0.045      -1.682      -0.018
# C(country_name)[T.Czech Republic]        10.6209      0.531     20.011      0.000       9.581      11.661
# C(country_name)[T.Denmark]                8.6666      0.559     15.509      0.000       7.571       9.762
# C(country_name)[T.Dominican Republic]     0.5947      0.515      1.155      0.248      -0.414       1.603
# C(country_name)[T.El Salvador]            2.4338      0.573      4.244      0.000       1.310       3.558
# C(country_name)[T.Estonia]               16.4433      0.352     46.652      0.000      15.753      17.134
# C(country_name)[T.Finland]               14.0830      0.375     37.559      0.000      13.348      14.818
# C(country_name)[T.France]                12.6888      0.351     36.164      0.000      12.001      13.376
# C(country_name)[T.Georgia]                2.3566      0.036     65.553      0.000       2.286       2.427
# C(country_name)[T.Germany]                8.8072      0.481     18.320      0.000       7.865       9.749
# C(country_name)[T.Hungary]               19.5864      0.461     42.453      0.000      18.682      20.491
# C(country_name)[T.Iceland]                9.0645      0.659     13.756      0.000       7.773      10.356
# C(country_name)[T.Indonesia]             -1.5101      0.553     -2.731      0.006      -2.594      -0.426
# C(country_name)[T.Ireland]                6.8247      0.409     16.704      0.000       6.024       7.625
# C(country_name)[T.Israel]                 0.9700      0.388      2.501      0.012       0.210       1.730
# C(country_name)[T.Italy]                  2.1313      0.322      6.615      0.000       1.500       2.763
# C(country_name)[T.Jamaica]               -3.4432      0.150    -22.925      0.000      -3.738      -3.149
# C(country_name)[T.Japan]                 17.9577      0.650     27.643      0.000      16.684      19.231
# C(country_name)[T.Kazakhstan]            26.2040      0.481     54.433      0.000      25.261      27.148
# C(country_name)[T.Korea, Rep.]           22.8791      0.697     32.822      0.000      21.513      24.245
# C(country_name)[T.Latvia]                19.1995      0.198     96.921      0.000      18.811      19.588
# C(country_name)[T.Lithuania]             32.8213      0.249    131.742      0.000      32.333      33.310
# C(country_name)[T.Luxembourg]             8.7286      0.612     14.270      0.000       7.530       9.927
# C(country_name)[T.Malaysia]               0.8754      0.699      1.252      0.211      -0.495       2.246
# C(country_name)[T.Malta]                  2.0038      0.532      3.768      0.000       0.962       3.046
# C(country_name)[T.Mexico]                 0.7073      0.660      1.072      0.284      -0.586       2.001
# C(country_name)[T.Moldova]               13.0916      0.536     24.415      0.000      12.041      14.143
# C(country_name)[T.Netherlands]            6.2803      0.614     10.228      0.000       5.077       7.484
# C(country_name)[T.New Zealand]            8.1481      0.589     13.836      0.000       6.994       9.302
# C(country_name)[T.North Macedonia]        0.8028      0.954      0.842      0.400      -1.067       2.672
# C(country_name)[T.Norway]                 8.4812      0.679     12.497      0.000       7.151       9.811
# C(country_name)[T.Panama]                -0.0910      0.478     -0.190      0.849      -1.028       0.846
# C(country_name)[T.Paraguay]               0.2588      0.561      0.461      0.645      -0.841       1.359
# C(country_name)[T.Peru]                  -1.1161      0.641     -1.740      0.082      -2.373       0.141
# C(country_name)[T.Poland]                11.2686      0.215     52.376      0.000      10.847      11.690
# C(country_name)[T.Portugal]               7.0841      0.351     20.183      0.000       6.396       7.772
# C(country_name)[T.Romania]                7.5393      0.502     15.008      0.000       6.555       8.524
# C(country_name)[T.Russian Federation]    35.2594      0.492     71.670      0.000      34.295      36.224
# C(country_name)[T.Serbia]                11.1612      0.140     79.466      0.000      10.886      11.436
# C(country_name)[T.Slovak Republic]        7.6301      0.085     89.485      0.000       7.463       7.797
# C(country_name)[T.Slovenia]              19.3080      0.486     39.708      0.000      18.355      20.261
# C(country_name)[T.South Africa]          16.1628      0.766     21.101      0.000      14.661      17.664
# C(country_name)[T.Spain]                  1.8369      0.072     25.374      0.000       1.695       1.979
# C(country_name)[T.Sweden]                10.5670      0.481     21.983      0.000       9.625      11.509
# C(country_name)[T.Switzerland]           12.8032      0.648     19.756      0.000      11.533      14.073
# C(country_name)[T.Thailand]               5.4916      0.834      6.588      0.000       3.858       7.125
# C(country_name)[T.Turkey]                -2.4089      0.289     -8.333      0.000      -2.975      -1.842
# C(country_name)[T.Ukraine]               23.1154      0.378     61.226      0.000      22.375      23.855
# C(country_name)[T.United Kingdom]         3.9201      0.557      7.044      0.000       2.829       5.011
# C(country_name)[T.United States]          8.9018      0.541     16.439      0.000       7.841       9.963
# C(country_name)[T.Uruguay]               12.2804      0.303     40.563      0.000      11.687      12.874
# C(country_name)[T.Uzbekistan]             4.9151      0.666      7.379      0.000       3.610       6.221
# C(year)[T.2001]                          -0.1837      0.141     -1.301      0.193      -0.461       0.093
# C(year)[T.2002]                          -0.2688      0.195     -1.381      0.167      -0.650       0.113
# C(year)[T.2003]                          -0.4441      0.272     -1.632      0.103      -0.977       0.089
# C(year)[T.2004]                          -0.6803      0.314     -2.169      0.030      -1.295      -0.066
# C(year)[T.2005]                          -0.7446      0.361     -2.062      0.039      -1.452      -0.037
# C(year)[T.2006]                          -1.0816      0.415     -2.604      0.009      -1.896      -0.268
# C(year)[T.2007]                          -1.2862      0.483     -2.661      0.008      -2.234      -0.339
# C(year)[T.2008]                          -1.0117      0.500     -2.024      0.043      -1.991      -0.032
# C(year)[T.2009]                          -1.1854      0.604     -1.962      0.050      -2.370      -0.001
# C(year)[T.2010]                          -1.7025      0.670     -2.541      0.011      -3.016      -0.389
# C(year)[T.2011]                          -1.8922      0.673     -2.811      0.005      -3.212      -0.573
# C(year)[T.2012]                          -1.8898      0.652     -2.900      0.004      -3.167      -0.612
# C(year)[T.2013]                          -2.0945      0.670     -3.125      0.002      -3.408      -0.781
# C(year)[T.2014]                          -2.1783      0.695     -3.136      0.002      -3.540      -0.817
# C(year)[T.2015]                          -2.3810      0.719     -3.310      0.001      -3.791      -0.971
# C(year)[T.2016]                          -2.6564      0.739     -3.595      0.000      -4.105      -1.208
# C(year)[T.2017]                          -2.8574      0.813     -3.515      0.000      -4.451      -1.264
# C(year)[T.2018]                          -2.9005      0.802     -3.616      0.000      -4.473      -1.328
# C(year)[T.2019]                          -3.0278      0.816     -3.711      0.000      -4.627      -1.429
# unemployment                              0.1767      0.061      2.875      0.004       0.056       0.297
# ==============================================================================
# Omnibus:                      196.518   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2604.260
# Skew:                          -0.199   Prob(JB):                         0.00
# Kurtosis:                       9.977   Cond. No.                         686.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
